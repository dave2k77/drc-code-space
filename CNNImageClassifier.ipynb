# %% [markdown]
# # Image Classification with Convolutional Neural Networks

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Exploring the CIFAR-10 Dataset

# %%
import tensorflow as tf
from tensorflow.keras import datasets

# Load the CIFAR-10 dataset included in keras
cifar10_data = datasets.cifar10

# split the CIFAR-10 dataset into training and testing sets.
(training_examples, training_labels), (test_examples, test_labels) = cifar10_data.load_data()

# Verify dimensions of the training and testing sets.
print(training_examples.shape)
print(test_examples.shape)
# Out:
# 2022-04-18 18:59:09.448101: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-18 18:59:09.448124: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# view a single example in the dataset
print(training_examples[7])

# view the corresponding label
print(training_labels[7])
# Out:
# [[[ 28  35  39]
#   [ 30  34  44]
#   [ 33  44  47]
#   ...
#   [ 43  56  45]
#   [ 52  64  53]
#   [ 46  58  47]]
#
#  [[ 27  30  38]
#   [ 27  28  41]
#   [ 21  31  39]
#   ...
#   [112 136  97]
#   [117 140 101]
#   [115 138 100]]
#
#  [[ 34  36  42]
#   [ 33  33  43]
#   [ 24  30  40]
#   ...
#   [175 208 143]
#   [177 209 144]
#   [176 208 143]]
#
#  ...
#
#  [[142 176 118]
#   [142 176 118]
#   [150 184 127]
#   ...
#   [134 175 119]
#   [128 168 112]
#   [134 175 119]]
#
#  [[140 176 124]
#   [145 180 129]
#   [150 186 134]
#   ...
#   [131 170 119]
#   [130 170 119]
#   [122 162 111]]
#
#  [[134 171 123]
#   [136 171 124]
#   [136 171 124]
#   ...
#   [106 144 100]
#   [104 142  99]
#   [101 140  96]]]
# [7]

# %%
# visualising a sample of the training dataset.
import numpy as np
import matplotlib.pyplot as plt

# create a mapping to the text label
label_set = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
unique_training_labels = np.unique(training_labels)

# print out the index - text name mapping
for i in range(len(unique_training_labels)):
    print(unique_training_labels[i], label_set[unique_training_labels[i]])
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %%
# create the canvas for our plots
plt.figure(figsize=(5,15))
num_classes = len(unique_training_labels)

# print out the first 10 training examples with their corresponding label.
for i in range(num_classes):
    plt.subplot(5, 2, i + 1)
    plt.title("Category: {}".format(label_set[training_labels[i][0]]))
    plt.imshow(training_examples[i])
plt.show()

# %% [markdown]
# ## CNN Classifier Architecture and Configurations

# %% [markdown]
# ### CNN Network Architecture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Network Model: Configurations

# %% [markdown]
# **Network Structure**
#
# |Layer  |Config. 1 | Config. 2 | Config. 3 | Config. 4 | Config. 5 | Config 6. |
# |-------|:--------:|:---------:|:---------:|:---------:|:---------:|:---------:|
# |CL     | 2        | 2         | 2         | 4         | 4         | 4         |
# |FCL    | 1        | 1         | 1         | 3         | 4         | 3         |
# |Dropout| -        | -         | 2         | 6         | 6         | 6         |
# |Pooling| -        | -         | -         | Max       | Max       | Max       |
# |Padding| same     | same      | same      | same      | same      | same      |
#
# **Hyperparameters Selection: configurations 1,2 and 3**
#
# |Hyperparameter     |Config. 1                   | Config. 2                  | Config. 3                  |
# |:------------------|:---------------------------|:---------------------------|:---------------------------|
# |Activation Function|ReLU and SoftMax            |ReLU and SoftMax            |ReLU and SoftMax            |
# |Optimizer          |Stochastic Gradient Descent |Adam                        |Adam                        |
# |Loss Function      |Categorical Cross Entropy   |Categorical Cross Entropy   |Categorical Cross Entropy   |
# |Number of Batches  |32                          |32                          |32                          |
# |Number of Epochs   |30                          |30                          |30                          |
# |Dropout Rate       |20%                         |20%                         |20%                         |
#
#
# **Hyperparameter Selections: configurations 4, 5 and 6**
#
# |Hyperparameter     | Config. 4                  | Config. 5                  | Config. 6                  |
# |:------------------|:---------------------------|:---------------------------|:---------------------------|
# |Activation Function|ReLU and SoftMax            |ReLU and Sigmoid            |ReLU and tanh            |
# |Optimizer          |Adam                        |Adam                        |Adam                        |
# |Loss Function      |Categorical Cross Entropy   |Categorical Cross Entropy   |Categorical Cross Entropy   |
# |Number of Batches  |32                          |32                          |32                          |
# |Number of Epochs   |30                          |30                          |30                          |
# |Dropout Rate       |20%                         |20%                         |20%                         |

# %% [markdown]
# ## Data Preprocessing

# %%
mean = np.mean(training_examples)
stddev = np.std(training_examples)
training_examples = (training_examples - mean) / stddev
test_examples = (test_examples - mean) / stddev

# encode labels to one-hot format
from tensorflow.keras.utils import to_categorical
training_labels = to_categorical(training_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# viewing the standardised data
training_examples[0]
# Out:
# array([[[-0.96192505, -0.91515971, -0.89957127],
#         [-1.21134019, -1.16457485, -1.1801633 ],
#         [-1.10222107, -1.13339796, -1.21134019],
#         ...,
#         [ 0.58133111,  0.17603151, -0.19809119],
#         [ 0.48780043,  0.06691239, -0.29162187],
#         [ 0.42544665,  0.05132394, -0.27603342]],
#
#        [[-1.63222823, -1.56987445, -1.56987445],
#         [-1.88164337, -1.88164337, -1.88164337],
#         [-1.60105134, -1.7569358 , -1.88164337],
#         ...,
#         [ 0.0357355 , -0.50986012, -1.02427884],
#         [-0.02661829, -0.58780235, -1.10222107],
#         [ 0.02014705, -0.52544856, -0.99310194]],
#
#        [[-1.49193222, -1.50752067, -1.554286  ],
#         [-1.63222823, -1.77252425, -1.88164337],
#         [-1.11780951, -1.46075533, -1.7569358 ],
#         ...,
#         [-0.04220673, -0.5722139 , -1.10222107],
#         [-0.01102984, -0.5722139 , -1.10222107],
#         [-0.18250275, -0.74368681, -1.22692864]],
#
#        ...,
#
#        [[ 1.36075342,  0.76839246, -0.38515255],
#         [ 1.25163429,  0.50338888, -1.3516362 ],
#         [ 1.20486895,  0.62809645, -1.47634377],
#         ...,
#         [ 0.612508  ,  0.19161996, -0.79045215],
#         [-1.00869039, -1.39840154, -1.77252425],
#         [-1.05545573, -1.3516362 , -1.56987445]],
#
#        [[ 0.92427692,  0.28515064, -0.38515255],
#         [ 0.8151578 ,  0.0357355 , -1.22692864],
#         [ 1.0178076 ,  0.36309287, -1.41398999],
#         ...,
#         [ 0.98663071,  0.42544665, -0.41632944],
#         [-0.3695641 , -0.91515971, -1.3516362 ],
#         [-0.58780235, -1.05545573, -1.3516362 ]],
#
#        [[ 0.87751159,  0.36309287, -0.07338363],
#         [ 0.73721557,  0.12926617, -0.41632944],
#         [ 0.90868848,  0.33191597, -0.52544856],
#         ...,
#         [ 1.48546098,  0.98663071,  0.30073908],
#         [ 0.47221199, -0.04220673, -0.5722139 ],
#         [ 0.0357355 , -0.44750633, -0.75927525]]])

# %% [markdown]
# ## CNN Implementation: Configuration 1

# %% [markdown]
# ### Auxiliary Function for Printing Graphs of Model Accurracies and Losses

# %%
# FUNCTION OF ACCURACIES AND LOSSES PLOTS

def model_analysis_plot (model_history):
    import matplotlib.pyplot as plt
    import numpy as np
    fig, axes = plt.subplots(2, 1, figsize=(5, 15))
    # analysis of accuracies
    axes[0].plot(range(1, len(model_history['accuracy']) + 1), model_history['accuracy'])
    axes[0].plot(range(1, len(model_history['val_accuracy']) + 1), model_history['val_accuracy'])
    axes[0].set_title('Model Accuracies')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xticks(np.arange(1, len(model_history['accuracy']) + 1, len(model_history['accuracy']) / 10))
    axes[0].legend(['training', 'validation'], loc='best')
    # analysis of losses
    axes[1].plot(range(1, len(model_history['loss']) + 1), model_history['loss'])
    axes[1].plot(range(1, len(model_history['val_loss']) + 1), model_history['val_loss'])
    axes[1].set_title('Model Losses')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].set_xticks(np.arange(1, len(model_history['loss']) + 1, len(model_history['loss']) / 10))
    axes[1].legend(['training', 'validation'], loc='best')
    plt.show()

# %% [markdown]
# ### Building the Network with Configuration 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D

model1 = Sequential()

# first convolution layer
model1.add(Conv2D(64, (5,5), strides=(2,2), padding="same", activation='relu', input_shape=(32,32, 3)))

# second convolution layer
model1.add(Conv2D(64, (3,3), strides=(2,2), padding="same", activation='relu'))

# flatten the output
model1.add(Flatten())

# add the fully connected layer
model1.add(Dense(10, activation="softmax"))

# compile the model
model1.compile(loss='categorical_crossentropy',
               optimizer='sgd',
               metrics=['accuracy', 'mse', 'mae'])
# Out:
# 2022-04-18 18:59:13.579888: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-18 18:59:13.579918: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-18 18:59:13.579937: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davianc-TP-E480): /proc/driver/nvidia/version does not exist
# 2022-04-18 18:59:13.580153: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Compiling and Summarising Model 1

# %%
model1.compile(loss='categorical_crossentropy',
               optimizer='sgd',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 10)                40970
#
# =================================================================
# Total params: 82,762
# Trainable params: 82,762
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 1

# %%
# saving and loading the model
import os
import pickle

# create the path for saving the model and its history
model1_path = "cifar10_model1.saved_model"
model1_history_path = "cifar10_model1.saved_model_history"

if os.path.exists(model1_path) and os.path.exists(model1_history_path):
    # Load trained model
    model1 = tf.keras.models.load_model(model1_path)
    history1 = pickle.load(open(model1_history_path, "rb"))
    model_analysis_plot(history1)
else:
    # Train new model
    tf.random.set_seed(12345)
    model1.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history1 = model1.history.history
    model1.save(model1_path)
    pickle.dump(history1, open(model1_history_path, "wb"))
    model_analysis_plot(history1)
# Out:
# Epoch 1/30
# 782/782 - 11s - loss: 1.8168 - accuracy: 0.3602 - mse: 0.0771 - mae: 0.1567 - val_loss: 1.6140 - val_accuracy: 0.4302 - val_mse: 0.0711 - val_mae: 0.1453 - 11s/epoch - 15ms/step
# Epoch 2/30
# 782/782 - 10s - loss: 1.5083 - accuracy: 0.4711 - mse: 0.0672 - mae: 0.1372 - val_loss: 1.4695 - val_accuracy: 0.4776 - val_mse: 0.0663 - val_mae: 0.1320 - 10s/epoch - 13ms/step
# 782/782 - 12s - loss: 0.6500 - accuracy: 0.7783 - mse: 0.0314 - mae: 0.0664 - val_loss: 1.0495 - val_accuracy: 0.6521 - val_mse: 0.0480 - val_mae: 0.0836 - 12s/epoch - 15ms/step
# Epoch 28/30
# 782/782 - 12s - loss: 0.6353 - accuracy: 0.7833 - mse: 0.0306 - mae: 0.0652 - val_loss: 0.9954 - val_accuracy: 0.6703 - val_mse: 0.0457 - val_mae: 0.0810 - 12s/epoch - 15ms/step
# Epoch 29/30
# 782/782 - 12s - loss: 0.6244 - accuracy: 0.7886 - mse: 0.0301 - mae: 0.0641 - val_loss: 1.1011 - val_accuracy: 0.6456 - val_mse: 0.0495 - val_mae: 0.0846 - 12s/epoch - 15ms/step
# Epoch 30/30
# 782/782 - 12s - loss: 0.6106 - accuracy: 0.7913 - mse: 0.0295 - mae: 0.0630 - val_loss: 1.0248 - val_accuracy: 0.6679 - val_mse: 0.0464 - val_mae: 0.0809 - 12s/epoch - 15ms/step
# 2022-04-18 19:05:07.799909: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: cifar10_model1.saved_model/assets

# %% [markdown]
# ### Summarising Model 1's Performance

# %%
print(f"Model 1 Training Accuracy: {history1['accuracy'][-1]:.4}")
print(f"Model 1 Validation Accuracy: {history1['val_accuracy'][-1]:.4}")
print(f"Model 1 Training Loss: {history1['loss'][-1]:.4}")
print(f"Model 1 Validation Loss: {history1['val_loss'][-1]:.4}")
print(f"Model 1 Training Mean Square Error: {history1['mse'][-1]:.4}")
print(f"Model 1 Validation Mean Square Error: {history1['val_mse'][-1]:.4}")
print(f"Model 1 Training Mean Absolute Error: {history1['mae'][-1]:.4}")
print(f"Model 1 Validation Mean Absolute Error: {history1['val_mae'][-1]:.4}")
# Out:
# Model 1 Training Accuracy: 0.7913
# Model 1 Validation Accuracy: 0.6679
# Model 1 Training Loss: 0.6106
# Model 1 Validation Loss: 1.025
# Model 1 Training Mean Square Error: 0.02954
# Model 1 Validation Mean Square Error: 0.04635
# Model 1 Training Mean Absolute Error: 0.063
# Model 1 Validation Mean Absolute Error: 0.08089

# %% [markdown]
# ## CCN Implementation: Configuration 2

# %% [markdown]
# ### Building the Network with Configuration 2

# %%
model2 = Sequential()

# first convolution layer
model2.add(Conv2D(64, (5,5), strides=(2,2), padding="same", activation='relu', input_shape=(32,32, 3)))

# second convolution layer
model2.add(Conv2D(64, (3,3), strides=(2,2), padding="same", activation='relu'))

# flatten the output
model2.add(Flatten())

# add the fully connected layer
model2.add(Dense(10, activation="softmax"))

# %% [markdown]
# ### Compiling and Summarising Model 2

# %%
# compile the model
model2.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        4864
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 82,762
# Trainable params: 82,762
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 2

# %%
# create the path for saving the model and its history
model2_path = "cifar10_model2.saved_model"
model2_history_path = "cifar10_model2.saved_model_history"

if os.path.exists(model2_path) and os.path.exists(model2_history_path):
    # Load trained model
    model2 = tf.keras.models.load_model(model2_path)
    history2 = pickle.load(open(model2_history_path, "rb"))
    model_analysis_plot(history2)
else:
    # Train new model
    tf.random.set_seed(12345)
    model2.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history2 = model2.history.history
    model2.save(model2_path)
    pickle.dump(history2, open(model2_history_path, "wb"))
    model_analysis_plot(history2)
# Out:
# Epoch 1/30
# 782/782 - 12s - loss: 1.4088 - accuracy: 0.5033 - mse: 0.0634 - mae: 0.1274 - val_loss: 1.1836 - val_accuracy: 0.5722 - val_mse: 0.0554 - val_mae: 0.1087 - 12s/epoch - 16ms/step
# Epoch 2/30
# 782/782 - 12s - loss: 1.0657 - accuracy: 0.6283 - mse: 0.0498 - mae: 0.1004 - val_loss: 1.0403 - val_accuracy: 0.6396 - val_mse: 0.0489 - val_mae: 0.0974 - 12s/epoch - 15ms/step
# Epoch 3/30
# 782/782 - 12s - loss: 0.9194 - accuracy: 0.6802 - mse: 0.0435 - mae: 0.0878 - val_loss: 0.9887 - val_accuracy: 0.6588 - val_mse: 0.0465 - val_mae: 0.0886 - 12s/epoch - 15ms/step
# Epoch 4/30
# 782/782 - 12s - loss: 0.8226 - accuracy: 0.7142 - mse: 0.0393 - mae: 0.0793 - val_loss: 0.9836 - val_accuracy: 0.6629 - val_mse: 0.0458 - val_mae: 0.0873 - 12s/epoch - 15ms/step
# Epoch 5/30
# 782/782 - 12s - loss: 0.7422 - accuracy: 0.7429 - mse: 0.0357 - mae: 0.0722 - val_loss: 0.9840 - val_accuracy: 0.6707 - val_mse: 0.0451 - val_mae: 0.0809 - 12s/epoch - 15ms/step
# Epoch 6/30
# 782/782 - 12s - loss: 0.6816 - accuracy: 0.7623 - mse: 0.0330 - mae: 0.0669 - val_loss: 0.9996 - val_accuracy: 0.6735 - val_mse: 0.0455 - val_mae: 0.0795 - 12s/epoch - 15ms/step
# Epoch 7/30
# 782/782 - 12s - loss: 0.6240 - accuracy: 0.7813 - mse: 0.0304 - mae: 0.0614 - val_loss: 1.0346 - val_accuracy: 0.6670 - val_mse: 0.0464 - val_mae: 0.0796 - 12s/epoch - 15ms/step
# Epoch 8/30
# 782/782 - 12s - loss: 0.5739 - accuracy: 0.7991 - mse: 0.0282 - mae: 0.0572 - val_loss: 1.0401 - val_accuracy: 0.6776 - val_mse: 0.0461 - val_mae: 0.0767 - 12s/epoch - 15ms/step
# Epoch 9/30
# 782/782 - 12s - loss: 0.5316 - accuracy: 0.8136 - mse: 0.0263 - mae: 0.0532 - val_loss: 1.1239 - val_accuracy: 0.6605 - val_mse: 0.0488 - val_mae: 0.0783 - 12s/epoch - 15ms/step
# Epoch 10/30
# 782/782 - 12s - loss: 0.4896 - accuracy: 0.8280 - mse: 0.0245 - mae: 0.0496 - val_loss: 1.1452 - val_accuracy: 0.6724 - val_mse: 0.0480 - val_mae: 0.0743 - 12s/epoch - 15ms/step
# Epoch 11/30
# 782/782 - 12s - loss: 0.4549 - accuracy: 0.8406 - mse: 0.0227 - mae: 0.0461 - val_loss: 1.2082 - val_accuracy: 0.6571 - val_mse: 0.0500 - val_mae: 0.0771 - 12s/epoch - 15ms/step
# Epoch 12/30
# 782/782 - 12s - loss: 0.1920 - accuracy: 0.9296 - mse: 0.0103 - mae: 0.0204 - val_loss: 2.1559 - val_accuracy: 0.6357 - val_mse: 0.0604 - val_mae: 0.0751 - 12s/epoch - 15ms/step
# Epoch 25/30
# 782/782 - 12s - loss: 0.1726 - accuracy: 0.9378 - mse: 0.0092 - mae: 0.0184 - val_loss: 2.2175 - val_accuracy: 0.6449 - val_mse: 0.0594 - val_mae: 0.0731 - 12s/epoch - 15ms/step
# Epoch 26/30
# 782/782 - 12s - loss: 0.1635 - accuracy: 0.9388 - mse: 0.0089 - mae: 0.0179 - val_loss: 2.3286 - val_accuracy: 0.6463 - val_mse: 0.0597 - val_mae: 0.0727 - 12s/epoch - 15ms/step
# Epoch 27/30
# 782/782 - 12s - loss: 0.1598 - accuracy: 0.9428 - mse: 0.0086 - mae: 0.0170 - val_loss: 2.5047 - val_accuracy: 0.6357 - val_mse: 0.0620 - val_mae: 0.0747 - 12s/epoch - 15ms/step
# Epoch 28/30
# 782/782 - 12s - loss: 0.1569 - accuracy: 0.9417 - mse: 0.0085 - mae: 0.0167 - val_loss: 2.4641 - val_accuracy: 0.6414 - val_mse: 0.0609 - val_mae: 0.0732 - 12s/epoch - 15ms/step
# Epoch 29/30
# 782/782 - 12s - loss: 0.1424 - accuracy: 0.9476 - mse: 0.0077 - mae: 0.0152 - val_loss: 2.6168 - val_accuracy: 0.6382 - val_mse: 0.0619 - val_mae: 0.0735 - 12s/epoch - 15ms/step
# Epoch 30/30
# 782/782 - 12s - loss: 0.1428 - accuracy: 0.9477 - mse: 0.0077 - mae: 0.0150 - val_loss: 2.7058 - val_accuracy: 0.6463 - val_mse: 0.0618 - val_mae: 0.0729 - 12s/epoch - 15ms/step
# INFO:tensorflow:Assets written to: cifar10_model2.saved_model/assets

# %% [markdown]
# ### Summarising Model 2's Performance

# %%
print(f"Model 2 Training Accuracy: {history2['accuracy'][-1]:.4}")
print(f"Model 2 Validation Accuracy: {history2['val_accuracy'][-1]:.4}")
print(f"Model 2 Training Loss: {history2['loss'][-1]:.4}")
print(f"Model 2 Validation Loss: {history2['val_loss'][-1]:.4}")
print(f"Model 2 Training Mean Square Error: {history2['mse'][-1]:.4}")
print(f"Model 2 Validation Mean Square Error: {history2['val_mse'][-1]:.4}")
print(f"Model 2 Training Mean Absolute Error: {history2['mae'][-1]:.4}")
print(f"Model 2 Validation Mean Absolute Error: {history2['val_mae'][-1]:.4}")
# Out:
# Model 2 Training Accuracy: 0.9477
# Model 2 Validation Accuracy: 0.6463
# Model 2 Training Loss: 0.1428
# Model 2 Validation Loss: 2.706
# Model 2 Training Mean Square Error: 0.0077
# Model 2 Validation Mean Square Error: 0.06178
# Model 2 Training Mean Absolute Error: 0.01497
# Model 2 Validation Mean Absolute Error: 0.07289

# %% [markdown]
# ## CNN Implementation: Configuration 3

# %% [markdown]
# ### Building the Network with Configuration 3

# %%
model3 = Sequential()

# first convolution layer
model3.add(Conv2D(64, (5,5), strides=(2,2), padding="same", activation='relu', input_shape=(32,32, 3)))

# add a first dropout layer
model3.add(Dropout(0.2))

# second convolution layer
model3.add(Conv2D(64, (3,3), strides=(2,2), padding="same", activation='relu'))

# flatten the output
model3.add(Flatten())

# add a second dropout layer
model3.add(Dropout(0.2))

# add the fully connected layer
model3.add(Dense(10, activation="softmax"))

# %% [markdown]
# ### Compiling and Summarising Model 3

# %%
# compile the model
model3.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        4864
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          36928
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 82,762
# Trainable params: 82,762
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 3

# %%
# create the path for saving the model and its history
model3_path = "cifar10_model3.saved_model"
model3_history_path = "cifar10_model3.saved_model_history"

if os.path.exists(model3_path) and os.path.exists(model3_history_path):
    # Load trained model
    model3 = tf.keras.models.load_model(model3_path)
    history3 = pickle.load(open(model3_history_path, "rb"))
    model_analysis_plot(history3)
else:
    # Train new model
    tf.random.set_seed(12345)
    model3.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history3 = model3.history.history
    model3.save(model3_path)
    pickle.dump(history3, open(model3_history_path, "wb"))
    model_analysis_plot(history3)
# Out:
# Epoch 1/30
# 782/782 - 16s - loss: 1.4753 - accuracy: 0.4770 - mse: 0.0661 - mae: 0.1321 - val_loss: 1.2316 - val_accuracy: 0.5530 - val_mse: 0.0574 - val_mae: 0.1145 - 16s/epoch - 20ms/step
# Epoch 2/30
# 782/782 - 15s - loss: 1.1574 - accuracy: 0.5935 - mse: 0.0538 - mae: 0.1079 - val_loss: 1.0630 - val_accuracy: 0.6247 - val_mse: 0.0500 - val_mae: 0.1025 - 15s/epoch - 20ms/step
# Epoch 3/30
# 782/782 - 15s - loss: 1.0307 - accuracy: 0.6365 - mse: 0.0486 - mae: 0.0972 - val_loss: 0.9903 - val_accuracy: 0.6536 - val_mse: 0.0464 - val_mae: 0.0923 - 15s/epoch - 20ms/step
# Epoch 4/30
# 782/782 - 15s - loss: 0.9557 - accuracy: 0.6645 - mse: 0.0453 - mae: 0.0904 - val_loss: 0.9626 - val_accuracy: 0.6668 - val_mse: 0.0453 - val_mae: 0.0920 - 15s/epoch - 20ms/step
# Epoch 5/30
# 782/782 - 15s - loss: 0.8966 - accuracy: 0.6854 - mse: 0.0427 - mae: 0.0853 - val_loss: 0.9427 - val_accuracy: 0.6738 - val_mse: 0.0443 - val_mae: 0.0883 - 15s/epoch - 20ms/step
# Epoch 6/30
# 782/782 - 15s - loss: 0.8577 - accuracy: 0.6988 - mse: 0.0411 - mae: 0.0817 - val_loss: 0.9389 - val_accuracy: 0.6758 - val_mse: 0.0438 - val_mae: 0.0862 - 15s/epoch - 20ms/step
# Epoch 7/30
# 782/782 - 15s - loss: 0.8178 - accuracy: 0.7144 - mse: 0.0392 - mae: 0.0780 - val_loss: 0.9301 - val_accuracy: 0.6832 - val_mse: 0.0432 - val_mae: 0.0811 - 15s/epoch - 20ms/step
# Epoch 8/30
# 782/782 - 15s - loss: 0.7902 - accuracy: 0.7219 - mse: 0.0382 - mae: 0.0754 - val_loss: 0.9070 - val_accuracy: 0.6865 - val_mse: 0.0426 - val_mae: 0.0826 - 15s/epoch - 20ms/step
# Epoch 9/30
# 782/782 - 15s - loss: 0.6165 - accuracy: 0.7811 - mse: 0.0307 - mae: 0.0592 - val_loss: 0.9033 - val_accuracy: 0.7029 - val_mse: 0.0412 - val_mae: 0.0734 - 15s/epoch - 20ms/step
# Epoch 22/30
# 782/782 - 15s - loss: 0.6112 - accuracy: 0.7831 - mse: 0.0304 - mae: 0.0584 - val_loss: 0.9111 - val_accuracy: 0.7050 - val_mse: 0.0416 - val_mae: 0.0741 - 15s/epoch - 20ms/step
# Epoch 23/30
# 782/782 - 15s - loss: 0.6068 - accuracy: 0.7841 - mse: 0.0303 - mae: 0.0582 - val_loss: 0.9273 - val_accuracy: 0.6949 - val_mse: 0.0422 - val_mae: 0.0741 - 15s/epoch - 20ms/step
# Epoch 24/30
# 782/782 - 15s - loss: 0.6036 - accuracy: 0.7862 - mse: 0.0300 - mae: 0.0577 - val_loss: 0.9252 - val_accuracy: 0.6974 - val_mse: 0.0422 - val_mae: 0.0734 - 15s/epoch - 20ms/step
# Epoch 25/30
# 782/782 - 15s - loss: 0.5923 - accuracy: 0.7896 - mse: 0.0295 - mae: 0.0565 - val_loss: 0.9306 - val_accuracy: 0.6974 - val_mse: 0.0423 - val_mae: 0.0751 - 15s/epoch - 20ms/step
# Epoch 26/30
# 782/782 - 15s - loss: 0.5835 - accuracy: 0.7931 - mse: 0.0291 - mae: 0.0561 - val_loss: 0.9488 - val_accuracy: 0.6947 - val_mse: 0.0430 - val_mae: 0.0752 - 15s/epoch - 20ms/step
# Epoch 27/30
# 782/782 - 15s - loss: 0.5854 - accuracy: 0.7912 - mse: 0.0292 - mae: 0.0560 - val_loss: 0.9297 - val_accuracy: 0.6997 - val_mse: 0.0420 - val_mae: 0.0728 - 15s/epoch - 20ms/step
# Epoch 28/30
# 782/782 - 15s - loss: 0.5829 - accuracy: 0.7913 - mse: 0.0291 - mae: 0.0556 - val_loss: 0.9334 - val_accuracy: 0.7010 - val_mse: 0.0420 - val_mae: 0.0720 - 15s/epoch - 20ms/step
# Epoch 29/30
# 782/782 - 15s - loss: 0.5778 - accuracy: 0.7914 - mse: 0.0291 - mae: 0.0555 - val_loss: 0.9568 - val_accuracy: 0.6988 - val_mse: 0.0429 - val_mae: 0.0733 - 15s/epoch - 20ms/step
# Epoch 30/30
# 782/782 - 15s - loss: 0.5707 - accuracy: 0.7990 - mse: 0.0285 - mae: 0.0544 - val_loss: 0.9272 - val_accuracy: 0.7039 - val_mse: 0.0418 - val_mae: 0.0719 - 15s/epoch - 20ms/step
# INFO:tensorflow:Assets written to: cifar10_model3.saved_model/assets

# %% [markdown]
# ### Summarising Model 3's Performance

# %%
print(f"Model 3 Training Accuracy: {history3['accuracy'][-1]:.4}")
print(f"Model 3 Validation Accuracy: {history3['val_accuracy'][-1]:.4}")
print(f"Model 3 Training Loss: {history3['loss'][-1]:.4}")
print(f"Model 3 Validation Loss: {history3['val_loss'][-1]:.4}")
print(f"Model 3 Training Mean Square Error: {history3['mse'][-1]:.4}")
print(f"Model 3 Validation Mean Square Error: {history3['val_mse'][-1]:.4}")
print(f"Model 3 Training Mean Absolute Error: {history3['mae'][-1]:.4}")
print(f"Model 3 Validation Mean Absolute Error: {history3['val_mae'][-1]:.4}")
# Out:
# Model 3 Training Accuracy: 0.799
# Model 3 Validation Accuracy: 0.7039
# Model 3 Training Loss: 0.5707
# Model 3 Validation Loss: 0.9272
# Model 3 Training Mean Square Error: 0.02847
# Model 3 Validation Mean Square Error: 0.0418
# Model 3 Training Mean Absolute Error: 0.05436
# Model 3 Validation Mean Absolute Error: 0.07185

# %% [markdown]
# ## CNN Implementation: Configuration 4

# %% [markdown]
# ### Building the Network with Configuration 4

# %%
model4 = Sequential()

# first convolution layer
model4.add(Conv2D(64, (4,4), strides=(1,1), padding="same", activation='relu', input_shape=(32,32, 3)))
# add a dropout layer
model4.add(Dropout(0.2))

# second convolution layer
model4.add(Conv2D(64, (2,2), strides=(2,2), padding="same", activation='relu'))

# add a second dropout layer
model4.add(Dropout(0.2))

# third convolution layer
model4.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu'))

# add a third dropout layer
model4.add(Dropout(0.2))

# fourth convolution layer
model4.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu'))

# add a pooling layer
model4.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

# add a fourth dropout layer
model4.add(Dropout(0.2))

# flatten the output
model4.add(Flatten())

# add a first fully connected layer
model4.add(Dense(64, activation="sigmoid"))

# add a fifth dropout layer.
model4.add(Dropout(0.2))

# add a second fully connected layer
model4.add(Dense(64, activation="sigmoid"))

# add a sixth dropout layer.
model4.add(Dropout(0.2))

# add a third fully connected layer
model4.add(Dense(10, activation="sigmoid"))

# %% [markdown]
# ### Compiling and Summarising Model 4

# %%
# compile the model
model4.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        3136
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        16448
#
#  dropout_3 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)        18464
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 32)         0
#  )
#
#  dropout_5 (Dropout)         (None, 8, 8, 32)          0
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 64)                131136
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 183,242
# Trainable params: 183,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 4

# %%
# create the path for saving the model and its history
model4_path = "cifar10_model4.saved_model"
model4_history_path = "cifar10_model4.saved_model_history"

if os.path.exists(model4_path) and os.path.exists(model4_history_path):
    # Load trained model
    model4 = tf.keras.models.load_model(model4_path)
    history4 = pickle.load(open(model4_history_path, "rb"))
    model_analysis_plot(history4)
else:
    # Train new model
    tf.random.set_seed(12345)
    model4.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history4 = model4.history.history
    model4.save(model4_path)
    pickle.dump(history4, open(model4_history_path, "wb"))
    model_analysis_plot(history4)
# Out:
# Epoch 1/30
# 782/782 - 68s - loss: 1.8288 - accuracy: 0.3197 - mse: 0.2570 - mae: 0.4569 - val_loss: 1.4823 - val_accuracy: 0.4718 - val_mse: 0.2408 - val_mae: 0.4145 - 68s/epoch - 87ms/step
# Epoch 2/30
# 782/782 - 68s - loss: 1.4396 - accuracy: 0.4758 - mse: 0.2367 - mae: 0.3981 - val_loss: 1.2622 - val_accuracy: 0.5458 - val_mse: 0.2221 - val_mae: 0.3737 - 68s/epoch - 87ms/step
# Epoch 3/30
# Epoch 28/30
# 782/782 - 67s - loss: 0.7133 - accuracy: 0.7561 - mse: 0.1609 - mae: 0.2622 - val_loss: 0.7247 - val_accuracy: 0.7523 - val_mse: 0.1573 - val_mae: 0.2554 - 67s/epoch - 85ms/step
# Epoch 29/30
# 782/782 - 67s - loss: 0.7091 - accuracy: 0.7572 - mse: 0.1609 - mae: 0.2617 - val_loss: 0.7257 - val_accuracy: 0.7544 - val_mse: 0.1576 - val_mae: 0.2565 - 67s/epoch - 85ms/step
# Epoch 30/30
# 782/782 - 67s - loss: 0.7064 - accuracy: 0.7583 - mse: 0.1611 - mae: 0.2614 - val_loss: 0.7318 - val_accuracy: 0.7522 - val_mse: 0.1559 - val_mae: 0.2552 - 67s/epoch - 85ms/step
# INFO:tensorflow:Assets written to: cifar10_model4.saved_model/assets

# %% [markdown]
# ### Summarising Model 4's Performance

# %%
print(f"Model 4 Training Accuracy: {history4['accuracy'][-1]:.4}")
print(f"Model 4 Validation Accuracy: {history4['val_accuracy'][-1]:.4}")
print(f"Model 4 Training Loss: {history4['loss'][-1]:.4}")
print(f"Model 4 Validation Loss: {history4['val_loss'][-1]:.4}")
print(f"Model 4 Training Mean Square Error: {history4['mse'][-1]:.4}")
print(f"Model 4 Validation Mean Square Error: {history4['val_mse'][-1]:.4}")
print(f"Model 4 Training Mean Absolute Error: {history4['mae'][-1]:.4}")
print(f"Model 4 Validation Mean Absolute Error: {history4['val_mae'][-1]:.4}")
# Out:
# Model 4 Training Accuracy: 0.7583
# Model 4 Validation Accuracy: 0.7522
# Model 4 Training Loss: 0.7064
# Model 4 Validation Loss: 0.7318
# Model 4 Training Mean Square Error: 0.1611
# Model 4 Validation Mean Square Error: 0.1559
# Model 4 Training Mean Absolute Error: 0.2614
# Model 4 Validation Mean Absolute Error: 0.2552

# %% [markdown]
# ## CNN Implementation: Configuration 5

# %% [markdown]
# ### Building the Network with Configuration 5

# %%
model5 = Sequential()

# first convolution layer
model5.add(Conv2D(64, (4,4), strides=(1,1), padding="same", activation='relu', input_shape=(32,32, 3)))

# add a first dropout layer
model5.add(Dropout(0.2))

# second convolution layer
model5.add(Conv2D(64, (2,2), strides=(2,2), padding="same", activation='relu'))

# add a second dropout layer
model5.add(Dropout(0.2))

# third convolution layer
model5.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu'))

# add a third dropout layer
model5.add(Dropout(0.2))

# fourth convolution layer
model5.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu'))

# add a pooling layer
model5.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

# add a fourth dropout layer.
model5.add(Dropout(0.2))

# flatten the output
model5.add(Flatten())

# add a first fully connected layer
model5.add(Dense(64, activation="relu"))

# add a fourth dropout layer.
model5.add(Dropout(0.2))

# add a second fully connected layer
model5.add(Dense(64, activation="relu"))

# add a fifth dropout layer.
model5.add(Dropout(0.2))

# add a second fully connected layer
model5.add(Dense(64, activation="relu"))

# add a fifth dropout layer.
model5.add(Dropout(0.2))

# add the fully connected layer
model5.add(Dense(10, activation="softmax"))

# %% [markdown]
# ### Compiling and Summarising Model 5

# %%
# compile the model
model5.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 64)        3136
#
#  dropout_8 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        16448
#
#  dropout_9 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 32)        18464
#
#  dropout_10 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_11 (Dropout)        (None, 8, 8, 32)          0
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 64)                131136
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 187,402
# Trainable params: 187,402
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 5

# %%
# create the path for saving the model and its history
model5_path = "cifar10_model5.saved_model"
model5_history_path = "cifar10_model5.saved_model_history"

if os.path.exists(model5_path) and os.path.exists(model5_history_path):
    # Load trained model
    model5 = tf.keras.models.load_model(model5_path)
    history5 = pickle.load(open(model5_history_path, "rb"))
    model_analysis_plot(history5)
else:
    # Train new model
    tf.random.set_seed(12345)
    model5.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history5 = model5.history.history
    model5.save(model5_path)
    pickle.dump(history5, open(model5_history_path, "wb"))
    model_analysis_plot(history5)

# %% [markdown]
# ### Summarising Model 5's Performance

# %%
print(f"Model 5 Training Accuracy: {history5['accuracy'][-1]:.4}")
print(f"Model 5 Validation Accuracy: {history5['val_accuracy'][-1]:.4}")
print(f"Model 5 Training Loss: {history5['loss'][-1]:.4}")
print(f"Model 5 Validation Loss: {history5['val_loss'][-1]:.4}")
print(f"Model 5 Training Mean Square Error: {history5['mse'][-1]:.4}")
print(f"Model 5 Validation Mean Square Error: {history5['val_mse'][-1]:.4}")
print(f"Model 5 Training Mean Absolute Error: {history5['mae'][-1]:.4}")
print(f"Model 5 Validation Mean Absolute Error: {history5['val_mae'][-1]:.4}")
# Out:
# Model 5 Training Accuracy: 0.7506
# Model 5 Validation Accuracy: 0.7541
# Model 5 Training Loss: 0.7391
# Model 5 Validation Loss: 0.7274
# Model 5 Training Mean Square Error: 0.03484
# Model 5 Validation Mean Square Error: 0.03413
# Model 5 Training Mean Absolute Error: 0.06968
# Model 5 Validation Mean Absolute Error: 0.0693

# %% [markdown]
# ## CNN Implementation: Configuration 6

# %% [markdown]
# ### Building the Network with Configuration 6

# %%
model6 = Sequential()

# first convolution layer
model6.add(Conv2D(64, (4,4), strides=(1,1), padding="same", activation='relu', input_shape=(32,32, 3),
                  kernel_initializer='he_normal', bias_initializer="zeros"))

# add a first dropout layer
model6.add(Dropout(0.2))

# second convolution layer
model6.add(Conv2D(64, (2,2), strides=(2,2), padding="same", activation='relu',
                  kernel_initializer='he_normal', bias_initializer="zeros"))

# add a second dropout layer
model6.add(Dropout(0.2))

# third convolution layer
model6.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu',
                  kernel_initializer='he_normal', bias_initializer="zeros"))

# add a third dropout layer
model6.add(Dropout(0.2))

# fourth convolution layer
model6.add(Conv2D(32, (3,3), strides=(1,1), padding="same", activation='relu',
                  kernel_initializer='he_normal', bias_initializer="zeros"))

# add a pooling layer
model6.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

# add a fourth dropout layer.
model6.add(Dropout(0.2))

# flatten the output
model6.add(Flatten())

# add a first fully connected layer
model6.add(Dense(64, activation="tanh"))

# add a fourth dropout layer.
model6.add(Dropout(0.2))

# add a second fully connected layer
model6.add(Dense(64, activation="tanh"))

# add a fifth dropout layer.
model6.add(Dropout(0.2))


# add the fully connected layer
model6.add(Dense(10, activation="tanh"))

# %% [markdown]
# ### Compiling and Summarising Model 6

# %%
# compile the model
model6.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy', 'mse', 'mae'])

# summarise the model
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 64)        3136
#
#  dropout_8 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        16448
#
#  dropout_9 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 32)        18464
#
#  dropout_10 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_11 (Dropout)        (None, 8, 8, 32)          0
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 64)                131136
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 187,402
# Trainable params: 187,402
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving, Loading and Training Model 6

# %%
# create the path for saving the model and its history
model6_path = "cifar10_model6.saved_model"
model6_history_path = "cifar10_model6.saved_model_history"

if os.path.exists(model6_path) and os.path.exists(model6_history_path):
    # Load trained model
    model6 = tf.keras.models.load_model(model6_path)
    history6 = pickle.load(open(model6_history_path, "rb"))
    model_analysis_plot(history6)
else:
    # Train new model
    tf.random.set_seed(12345)
    model6.fit(training_examples, training_labels,
               batch_size = 64,
               epochs = 30,
               verbose = 2,
               validation_data = (test_examples, test_labels))
    history6 = model6.history.history
    model6.save(model6_path)
    pickle.dump(history6, open(model6_history_path, "wb"))
    model_analysis_plot(history6)
# Out:
# Epoch 1/30
# 782/782 - 68s - loss: 5.1968 - accuracy: 0.0987 - mse: 0.8465 - mae: 0.8597 - val_loss: 4.6479 - val_accuracy: 0.1000 - val_mse: 0.9346 - val_mae: 0.9191 - 68s/epoch - 87ms/step
# Epoch 2/30
# 782/782 - 66s - loss: 4.6618 - accuracy: 0.1027 - mse: 0.8831 - mae: 0.8895 - val_loss: 4.6468 - val_accuracy: 0.1000 - val_mse: 0.9253 - val_mae: 0.9147 - 66s/epoch - 85ms/step
# Epoch 3/30
# 782/782 - 67s - loss: 4.6563 - accuracy: 0.1003 - mse: 0.8857 - mae: 0.8909 - val_loss: 4.6463 - val_accuracy: 0.1000 - val_mse: 0.9280 - val_mae: 0.9158 - 67s/epoch - 86ms/step
# Epoch 4/30
# 782/782 - 67s - loss: 4.6673 - accuracy: 0.1021 - mse: 0.8507 - mae: 0.8702 - val_loss: 4.6415 - val_accuracy: 0.1000 - val_mse: 0.9103 - val_mae: 0.9077 - 67s/epoch - 85ms/step
# Epoch 5/30
# 782/782 - 66s - loss: 4.6582 - accuracy: 0.1015 - mse: 0.8711 - mae: 0.8828 - val_loss: 4.6477 - val_accuracy: 0.1000 - val_mse: 0.9352 - val_mae: 0.9194 - 66s/epoch - 85ms/step
# Epoch 6/30
# 782/782 - 66s - loss: 4.6521 - accuracy: 0.1008 - mse: 0.8999 - mae: 0.8991 - val_loss: 4.6482 - val_accuracy: 0.1000 - val_mse: 0.9347 - val_mae: 0.9193 - 66s/epoch - 85ms/step
# Epoch 7/30
# 782/782 - 66s - loss: 4.6591 - accuracy: 0.1015 - mse: 0.8581 - mae: 0.8731 - val_loss: 4.6350 - val_accuracy: 0.0996 - val_mse: 0.8918 - val_mae: 0.8976 - 66s/epoch - 85ms/step
# Epoch 8/30
# 782/782 - 67s - loss: 4.6709 - accuracy: 0.1069 - mse: 0.8568 - mae: 0.8717 - val_loss: 4.6388 - val_accuracy: 0.1000 - val_mse: 0.8902 - val_mae: 0.8970 - 67s/epoch - 85ms/step
# Epoch 21/30
# 782/782 - 66s - loss: 7.8713 - accuracy: 0.1002 - mse: 0.9274 - mae: 0.9062 - val_loss: 6.7749 - val_accuracy: 0.1000 - val_mse: 0.9881 - val_mae: 0.9368 - 66s/epoch - 85ms/step
# Epoch 22/30
# 782/782 - 66s - loss: 6.0367 - accuracy: 0.0989 - mse: 0.9087 - mae: 0.8927 - val_loss: 5.7237 - val_accuracy: 0.1000 - val_mse: 0.8599 - val_mae: 0.8645 - 66s/epoch - 85ms/step
# Epoch 23/30
# 782/782 - 66s - loss: 6.0697 - accuracy: 0.0992 - mse: 0.8685 - mae: 0.8568 - val_loss: 5.2439 - val_accuracy: 0.1000 - val_mse: 0.6740 - val_mae: 0.7227 - 66s/epoch - 84ms/step
# Epoch 24/30
# 782/782 - 66s - loss: 4.8496 - accuracy: 0.1007 - mse: 0.8068 - mae: 0.8426 - val_loss: 4.6190 - val_accuracy: 0.1000 - val_mse: 0.7928 - val_mae: 0.8447 - 66s/epoch - 84ms/step
# Epoch 25/30
# 782/782 - 66s - loss: 4.6397 - accuracy: 0.1015 - mse: 0.8225 - mae: 0.8548 - val_loss: 4.6328 - val_accuracy: 0.1000 - val_mse: 0.8477 - val_mae: 0.8738 - 66s/epoch - 84ms/step
# Epoch 26/30
# 782/782 - 66s - loss: 4.6335 - accuracy: 0.0995 - mse: 0.8072 - mae: 0.8455 - val_loss: 4.6305 - val_accuracy: 0.1000 - val_mse: 0.8447 - val_mae: 0.8724 - 66s/epoch - 84ms/step
# Epoch 27/30
# 782/782 - 66s - loss: 4.6303 - accuracy: 0.0982 - mse: 0.8032 - mae: 0.8431 - val_loss: 4.6257 - val_accuracy: 0.1000 - val_mse: 0.8184 - val_mae: 0.8554 - 66s/epoch - 84ms/step
# Epoch 28/30
# 782/782 - 66s - loss: 4.6264 - accuracy: 0.1002 - mse: 0.7558 - mae: 0.8127 - val_loss: 4.6063 - val_accuracy: 0.1000 - val_mse: 0.7690 - val_mae: 0.8250 - 66s/epoch - 85ms/step
# Epoch 29/30
# 782/782 - 66s - loss: 4.6386 - accuracy: 0.1002 - mse: 0.7604 - mae: 0.8142 - val_loss: 4.5933 - val_accuracy: 0.1000 - val_mse: 0.7385 - val_mae: 0.8055 - 66s/epoch - 84ms/step
# Epoch 30/30
# 782/782 - 66s - loss: 4.6268 - accuracy: 0.1004 - mse: 0.7122 - mae: 0.7789 - val_loss: 4.6069 - val_accuracy: 0.1000 - val_mse: 0.7811 - val_mae: 0.8308 - 66s/epoch - 84ms/step
# INFO:tensorflow:Assets written to: cifar10_model6.saved_model/assets

# %% [markdown]
# ### Summarising Model 6's Performance

# %%
print(f"Model 6 Training Accuracy: {history6['accuracy'][-1]:.4}")
print(f"Model 6 Validation Accuracy: {history6['val_accuracy'][-1]:.4}")
print(f"Model 6 Training Loss: {history6['loss'][-1]:.4}")
print(f"Model 6 Validation Loss: {history6['val_loss'][-1]:.4}")
print(f"Model 6 Training Mean Square Error: {history6['mse'][-1]:.4}")
print(f"Model 6 Validation Mean Square Error: {history6['val_mse'][-1]:.4}")
print(f"Model 6 Training Mean Absolute Error: {history6['mae'][-1]:.4}")
print(f"Model 6 Validation Mean Absolute Error: {history6['val_mae'][-1]:.4}")
# Out:
# Model 6 Training Accuracy: 0.1004
# Model 6 Validation Accuracy: 0.1
# Model 6 Training Loss: 4.627
# Model 6 Validation Loss: 4.607
# Model 6 Training Mean Square Error: 0.7122
# Model 6 Validation Mean Square Error: 0.7811
# Model 6 Training Mean Absolute Error: 0.7789
# Model 6 Validation Mean Absolute Error: 0.8308

# %% [markdown]
# ## Accuracy Comparison across Configurations

# %%
import matplotlib.pyplot as plt
import numpy as np
train_acc = [x['accuracy'][-1] for x in (history1, history2, history3, history4, history5, history6)]
val_acc = [x['val_accuracy'][-1] for x in (history1, history2, history3, history4, history5, history6)]
train_loss = [x['loss'][-1] for x in (history1, history2, history3, history4, history5, history6)]
val_loss = [x['val_loss'][-1] for x in (history1, history2, history3, history4, history5, history6)]
config_id = np.array([1, 2, 3, 4, 5, 6])

fig, axes = plt.subplots(2, 2, figsize=(15, 5))
axes = axes.flatten()
axes[0].plot(config_id, train_acc, color='blue')
axes[0].set_title('Training Accuracy Trend')
axes[1].plot(config_id, val_acc, color='orange')
axes[1].set_title('Validation Accuracy Trend')
axes[2].plot(config_id, train_loss, color='blue')
axes[2].set_title('Training Loss Trend')
axes[3].plot(config_id, val_loss, color='orange')
axes[3].set_title('Validation Loss Trend')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Error Comparison across Configurations

# %%
train_mse = [x['mse'][-1] for x in (history1, history2, history3, history4, history5, history6)]
val_mse = [x['val_mse'][-1] for x in (history1, history2, history3, history4, history5, history6)]
train_mae = [x['mae'][-1] for x in (history1, history2, history3, history4, history5, history6)]
val_mae = [x['val_mae'][-1] for x in (history1, history2, history3, history4, history5, history6)]
config_id = np.array([1, 2, 3, 4, 5, 6])

fig, axes = plt.subplots(2, 2, figsize=(15, 5))
axes = axes.flatten()
axes[0].plot(config_id, train_mse, color='blue')
axes[0].set_title('Training MSE Trend')
axes[1].plot(config_id, val_mse, color='orange')
axes[1].set_title('Validation MSE Trend')
axes[2].plot(config_id, train_mae, color='blue')
axes[2].set_title('Training MAE Trend')
axes[3].plot(config_id, val_mae, color='orange')
axes[3].set_title('Validation MAE Trend')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Best Model Detection

# %%
best_model_index = np.argmax([x["val_accuracy"][-1] + x["accuracy"][-1] for x in (history4, history5)])
best_model = (model4, model5)[best_model_index]
history = (history4, history5)[best_model_index]
test_vectors = (training_examples, test_examples)[best_model_index]

print(f"Best Model: {best_model_index + 1}")
print(f"Training Accuracy: {history['accuracy'][-1]:.4}")
print(f"Validation Accuracy: {history['val_accuracy'][-1]:.4}")
print(f"Training MSE: {history['mse'][-1]:.4}")
print(f"Validation MSE: {history['val_mse'][-1]:.4}")
print(f"Training MAE: {history['mae'][-1]:.4}")
print(f"Validation MAE: {history['val_mae'][-1]:.4}")
# Out:
# Best Model: 1
# Training Accuracy: 0.7583
# Validation Accuracy: 0.7522
# Training MSE: 0.1611
# Validation MSE: 0.1559
# Training MAE: 0.2614
# Validation MAE: 0.2552
